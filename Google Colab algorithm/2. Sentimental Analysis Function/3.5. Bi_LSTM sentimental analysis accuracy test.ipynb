# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.3)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (3.8.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.4.3)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.7.3)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2020.4.5.1)

# %%
# %tensorflow_version 1.x
import os
import tensorflow as tf
from konlpy.tag import Okt

import gensim
import numpy as np
# Out:
# TensorFlow 1.x selected.

# %%
class Word2Vec():
    
    def __init__(self):
        None

    def tokenize(self, doc): # 토크나이즈 하는 부분
        pos_tagger = Okt()
        return ['/'.join(t) for t in pos_tagger.pos(doc, norm=True, stem=True)] # 품사 테깅하는 부분
    
    def read_data(self, filename): # 데이터 읽는 부분 
        with open(filename, 'r',encoding='utf-8') as f:
            data = [line.split('\t') for line in f.read().splitlines()]
            data = data[1:]
        return data  
    
    def Word2vec_model(self, model_name): # word2vec gensim모델을 불러들이는 부분
        model = gensim.models.word2vec.Word2Vec.load(model_name)
        return model
    
    # 한글 단어를 미리 프리트레이닝된 word2vec 모델에 lookup 테이블을 통해서 불러들이는 부분
    # 워드를 벡터로 바꾸는 부분
    def Convert2Vec(self, model_name, doc):  # Convert corpus into vectors
        word_vec = []
        model = gensim.models.word2vec.Word2Vec.load(model_name)
        for sent in doc:
            sub = []
            for word in sent: # 단어가 트레이닝된 단어장에 있으면 벡터를 불러들이고
                if(word in model.wv.vocab):
                    sub.append(model.wv[word])
                else: # 없다면 유니폼 분포를 따르는 어떤 램덤한 벡터를 생성하게 된다. 즉, OOV가 된다
                    sub.append(np.random.uniform(-0.25,0.25,300)) ## used for Out Of Vocaburaly words
            word_vec.append(sub)
        
        return np.array(word_vec)
    
    # 단어 사전에 제일 긴 단어길이에 맞춰 다른 단어들도 0으로 채워주기 위한 함수
    def Zero_padding(self, train_batch_X, Batch_size, Maxseq_length, Vector_size):
        zero_pad = np.zeros((Batch_size, Maxseq_length, Vector_size))
        for i in range(Batch_size):
            zero_pad[i,:np.shape(train_batch_X[i])[0],:np.shape(train_batch_X[i])[1]] = train_batch_X[i]
            
        return zero_pad
    
    # 원핫인코딩 기법
    def One_hot(self, data):
        index_dict = {value:index for index,value in enumerate(set(data))}
        result = []
        
        for value in data:
            one_hot = np.zeros(len(index_dict))
            index = index_dict[value]
            one_hot[index] = 1
            result.append(one_hot)
        
        return np.array(result)

# %%
class Bi_LSTM():

    def __init__(self, lstm_units, num_class, keep_prob):
        self.lstm_units = lstm_units

        with tf.variable_scope('forward', reuse=tf.AUTO_REUSE):
            self.lstm_fw_cell = tf.nn.rnn_cell.LSTMCell(lstm_units, forget_bias=1.0, state_is_tuple=True)
            self.lstm_fw_cell = tf.contrib.rnn.DropoutWrapper(self.lstm_fw_cell, output_keep_prob=keep_prob)

        with tf.variable_scope('backward', reuse=tf.AUTO_REUSE):
            self.lstm_bw_cell = tf.nn.rnn_cell.LSTMCell(lstm_units, forget_bias=1.0, state_is_tuple=True)
            self.lstm_bw_cell = tf.contrib.rnn.DropoutWrapper(self.lstm_bw_cell, output_keep_prob=keep_prob)

        with tf.variable_scope('Weights', reuse=tf.AUTO_REUSE):
            self.W = tf.get_variable(name="W", shape=[2 * lstm_units, num_class],
                                     dtype=tf.float32, initializer=tf.contrib.layers.xavier_initializer())
            self.b = tf.get_variable(name="b", shape=[num_class], dtype=tf.float32,
                                     initializer=tf.zeros_initializer())

    def logits(self, X, W, b, seq_len):
        (output_fw, output_bw), states = tf.nn.bidirectional_dynamic_rnn(self.lstm_fw_cell, self.lstm_bw_cell,
                                                                         dtype=tf.float32,
                                                                         inputs=X, sequence_length=seq_len)
        # concat fw, bw 
        outputs = tf.concat([states[0][1], states[1][1]], axis=1) # final states
        # final state를 fully connected layer를 통해서 prediction하게 된다.
        pred = tf.matmul(outputs, W) + b # softmax
        return pred

    def model_build(self, logits, labels, learning_rate=0.001):
        with tf.variable_scope("loss"):
            loss = tf.reduce_mean(
                tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=labels))  # Softmax loss
            optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)  # Adam Optimizer
        return loss, optimizer

    # Tensorboard를 통해 그래프를 만들때 쓰는 부분
    def graph_build(self):
        self.loss = tf.placeholder(tf.float32)
        self.acc = tf.placeholder(tf.float32)
        tf.summary.scalar('Loss', self.loss)
        tf.summary.scalar('Accuracy', self.acc)
        merged = tf.summary.merge_all()
        return merged

# %%
W2V = Word2Vec()
os.chdir("..")
test_data = W2V.read_data("/content/gdrive/My Drive/Colab Notebooks/GraduationProject/Word2Vec/Movie_rating_data/ratings_test.txt")

# tokenize the data we have.
# about 40 mins
print("Tokenize Start!\nCould take minutes...")
tokens = [[W2V.tokenize(row[1]),int(row[2])] for row in test_data if W2V.tokenize(row[1]) != []]
tokens = np.array(tokens)
print("Tokenize Done!")
# Out:
# Tokenize Start!
# Could take minutes...
# Tokenize Done!

# %%
test_X = tokens[:,0]
test_Y = tokens[:,1]

Batch_size = 32
test_size = len(test_X)
test_batch = int(test_size / Batch_size)
seq_length = [len(x) for x in test_X]
Vector_size = 300
Maxseq_length = 95   ## Max length of training data
learning_rate = 0.001
lstm_units = 128
num_class = 2
keep_prob = 1.0

# %%
test_Y_ = W2V.One_hot(test_Y)  ## Convert to One-hot
test_X_ = W2V.Convert2Vec("/content/gdrive/My Drive/Colab Notebooks/GraduationProject/Word2Vec/Word2vec.model",test_X)  ## import word2vec model where you have trained before

X = tf.placeholder(tf.float32, shape = [None, Maxseq_length, Vector_size], name = 'X')
Y = tf.placeholder(tf.float32, shape = [None, num_class], name = 'Y')
seq_len = tf.placeholder(tf.int32, shape = [None])
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
BiLSTM = Bi_LSTM(lstm_units, num_class, keep_prob)

with tf.variable_scope("loss", reuse = tf.AUTO_REUSE):
    logits = BiLSTM.logits(X, BiLSTM.W, BiLSTM.b, seq_len)
    loss, optimizer = BiLSTM.model_build(logits, Y, learning_rate)

prediction = tf.nn.softmax(logits)
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

modelName = "/content/gdrive/My Drive/Colab Notebooks/GraduationProject/Bi_LSTM/BiLSTM_model_Epoch_13.ckpt"
init = tf.global_variables_initializer()
saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From <ipython-input-10-ae8abc05ec34>:7: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-10-ae8abc05ec34>:23: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.Bidirectional(keras.layers.RNN(cell))`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py:464: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
with tf.Session() as sess:
    
    sess.run(init)
    # load the variables from disk.
    saver.restore(sess, modelName)
    print("Model restored")

    total_acc = 0

    for step in range(test_batch):

        test_batch_X = test_X_[step*Batch_size : step*Batch_size+Batch_size]
        test_batch_Y = test_Y_[step*Batch_size : step*Batch_size+Batch_size]
        batch_seq_length = seq_length[step*Batch_size : step*Batch_size+Batch_size]
        test_batch_X = W2V.Zero_padding(test_batch_X, Batch_size, Maxseq_length, Vector_size)

        acc = sess.run(accuracy , feed_dict={X: test_batch_X, Y: test_batch_Y, seq_len: batch_seq_length})
        print("step :{} Accuracy : {}".format(step+1,acc))
        total_acc += acc/test_batch

    print("Total Accuracy : {}".format(total_acc))
# Out:
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Colab Notebooks/GraduationProject/Bi_LSTM/BiLSTM_model_Epoch_13.ckpt
# Model restored
# step :1 Accuracy : 0.84375
# step :2 Accuracy : 0.8125
# step :3 Accuracy : 0.875
# step :4 Accuracy : 0.78125
# step :5 Accuracy : 0.875
# step :6 Accuracy : 0.875
# step :7 Accuracy : 0.9375
# step :8 Accuracy : 0.875
# step :9 Accuracy : 0.84375
# step :10 Accuracy : 0.84375
# step :11 Accuracy : 0.75
# step :12 Accuracy : 0.90625
# step :13 Accuracy : 0.90625
# step :14 Accuracy : 0.875
# step :15 Accuracy : 0.78125
# step :16 Accuracy : 0.71875
# step :17 Accuracy : 0.78125
# step :18 Accuracy : 0.9375
# step :19 Accuracy : 0.875
# step :20 Accuracy : 0.9375
# step :21 Accuracy : 0.75
# step :22 Accuracy : 0.8125
# step :23 Accuracy : 0.84375
# step :24 Accuracy : 0.8125
# step :25 Accuracy : 0.875
# step :26 Accuracy : 0.78125
# step :27 Accuracy : 0.78125
# step :28 Accuracy : 0.8125
# step :29 Accuracy : 0.96875
# step :30 Accuracy : 0.71875
# step :31 Accuracy : 0.875
# step :32 Accuracy : 0.875
# step :33 Accuracy : 0.875
# step :34 Accuracy : 0.875
# step :35 Accuracy : 0.9375
# step :36 Accuracy : 0.90625
# step :37 Accuracy : 0.84375
# step :38 Accuracy : 0.78125
# step :39 Accuracy : 0.84375
# step :40 Accuracy : 0.84375
# step :41 Accuracy : 0.75
# step :42 Accuracy : 0.9375
# step :43 Accuracy : 0.6875
# step :44 Accuracy : 0.78125
# step :45 Accuracy : 0.9375
# step :46 Accuracy : 0.84375
# step :47 Accuracy : 0.84375
# step :48 Accuracy : 0.96875
# step :49 Accuracy : 0.84375
# step :50 Accuracy : 0.90625
# step :51 Accuracy : 0.875
# step :52 Accuracy : 0.78125
# step :53 Accuracy : 0.875
# step :54 Accuracy : 0.6875
# step :55 Accuracy : 0.875
# step :56 Accuracy : 0.875
# step :57 Accuracy : 0.875
# step :58 Accuracy : 0.90625
# step :59 Accuracy : 0.9375
# step :60 Accuracy : 0.84375
# step :61 Accuracy : 0.84375
# step :62 Accuracy : 0.9375
# step :63 Accuracy : 0.875
# step :64 Accuracy : 0.8125
# step :65 Accuracy : 0.8125
# step :697 Accuracy : 0.78125
# step :698 Accuracy : 0.90625
# step :699 Accuracy : 0.78125
# step :700 Accuracy : 0.90625
# step :701 Accuracy : 0.9375
# step :702 Accuracy : 0.90625
# step :703 Accuracy : 0.84375
# step :704 Accuracy : 0.75
# step :705 Accuracy : 0.78125
# step :706 Accuracy : 0.84375
# step :707 Accuracy : 0.78125
# step :708 Accuracy : 0.78125
# step :709 Accuracy : 0.8125
# step :710 Accuracy : 0.78125
# step :711 Accuracy : 0.90625
# step :712 Accuracy : 0.71875
# step :713 Accuracy : 0.75
# step :714 Accuracy : 0.90625
# step :715 Accuracy : 0.8125
# step :716 Accuracy : 0.75
# step :717 Accuracy : 0.90625
# step :718 Accuracy : 0.9375
# step :719 Accuracy : 0.84375
# step :720 Accuracy : 0.90625
# step :721 Accuracy : 0.90625
# step :722 Accuracy : 0.9375
# step :723 Accuracy : 0.78125
# step :724 Accuracy : 0.875
# step :725 Accuracy : 0.78125
# step :726 Accuracy : 0.84375
# step :727 Accuracy : 0.875
# step :728 Accuracy : 0.875
# step :729 Accuracy : 0.90625
# step :730 Accuracy : 0.875
# step :731 Accuracy : 0.84375
# step :732 Accuracy : 0.96875
# step :733 Accuracy : 0.8125
# step :734 Accuracy : 0.875
# step :735 Accuracy : 0.875
# step :736 Accuracy : 0.8125
# step :737 Accuracy : 0.875
# step :738 Accuracy : 0.90625
# step :739 Accuracy : 0.84375
# step :740 Accuracy : 0.90625
# step :741 Accuracy : 0.9375
# step :742 Accuracy : 0.84375
# step :743 Accuracy : 0.90625
# step :744 Accuracy : 0.9375
# step :745 Accuracy : 0.8125
# step :746 Accuracy : 0.8125
# step :747 Accuracy : 0.75
# step :748 Accuracy : 0.875
# step :749 Accuracy : 0.84375
# step :750 Accuracy : 0.875
# step :751 Accuracy : 0.8125
# step :752 Accuracy : 0.84375
# step :753 Accuracy : 0.90625
# step :754 Accuracy : 0.9375
# step :755 Accuracy : 0.75
# step :756 Accuracy : 0.9375
# step :757 Accuracy : 0.875
# step :758 Accuracy : 0.78125
# step :759 Accuracy : 0.84375
# step :760 Accuracy : 0.9375
# step :761 Accuracy : 0.8125
# step :762 Accuracy : 0.75
# step :763 Accuracy : 0.875
# step :764 Accuracy : 0.84375
# step :765 Accuracy : 0.90625
# step :766 Accuracy : 0.8125
# step :767 Accuracy : 0.90625
# step :768 Accuracy : 0.875
# step :769 Accuracy : 0.78125
# step :770 Accuracy : 0.90625
# step :771 Accuracy : 0.90625
# step :772 Accuracy : 0.875
# step :773 Accuracy : 0.875
# step :774 Accuracy : 0.84375
# step :775 Accuracy : 0.90625
# step :776 Accuracy : 0.84375
# step :777 Accuracy : 0.78125
# step :778 Accuracy : 0.875
# step :779 Accuracy : 0.84375
# step :780 Accuracy : 0.8125
# step :781 Accuracy : 0.84375
# step :782 Accuracy : 0.9375
# step :783 Accuracy : 0.8125
# step :784 Accuracy : 0.90625
# step :785 Accuracy : 0.90625
# step :786 Accuracy : 0.84375
# step :787 Accuracy : 0.875
# step :788 Accuracy : 0.84375
# step :789 Accuracy : 0.90625
# step :790 Accuracy : 0.90625
# step :791 Accuracy : 0.875
# step :792 Accuracy : 0.9375
# step :793 Accuracy : 0.90625
# step :794 Accuracy : 0.84375
# step :795 Accuracy : 0.875
# step :796 Accuracy : 0.875
# step :797 Accuracy : 0.875
# step :798 Accuracy : 0.90625
# step :799 Accuracy : 0.875
# step :800 Accuracy : 0.78125
# step :801 Accuracy : 0.9375
# step :802 Accuracy : 0.90625
# step :803 Accuracy : 0.8125
# step :804 Accuracy : 0.8125
# step :805 Accuracy : 0.78125
# step :806 Accuracy : 0.90625
# step :807 Accuracy : 0.90625
# step :808 Accuracy : 0.90625
# step :809 Accuracy : 0.75
# step :810 Accuracy : 0.84375
# step :811 Accuracy : 0.90625
# step :812 Accuracy : 0.78125
# step :813 Accuracy : 0.875
# step :814 Accuracy : 0.84375
# step :815 Accuracy : 0.875
# step :816 Accuracy : 0.84375
# step :817 Accuracy : 0.84375
# step :818 Accuracy : 0.78125
# step :819 Accuracy : 0.84375
# step :820 Accuracy : 0.84375
# step :821 Accuracy : 0.9375
# step :822 Accuracy : 0.8125
# step :823 Accuracy : 0.84375
# step :824 Accuracy : 0.78125
# step :825 Accuracy : 0.78125
# step :826 Accuracy : 0.84375
# step :827 Accuracy : 0.78125
# step :828 Accuracy : 0.78125
# step :829 Accuracy : 0.75
# step :830 Accuracy : 0.8125
# step :831 Accuracy : 0.875
# step :832 Accuracy : 0.875
# step :833 Accuracy : 0.84375
# step :834 Accuracy : 0.9375
# step :835 Accuracy : 0.9375
# step :836 Accuracy : 0.84375
# step :837 Accuracy : 0.75
# step :838 Accuracy : 0.875
# step :839 Accuracy : 0.84375
# step :840 Accuracy : 0.90625
# step :841 Accuracy : 0.8125
# step :842 Accuracy : 0.84375
# step :843 Accuracy : 0.84375
# step :844 Accuracy : 0.84375
# step :845 Accuracy : 0.90625
# step :846 Accuracy : 0.84375
# step :847 Accuracy : 0.84375
# step :848 Accuracy : 0.84375
# step :849 Accuracy : 0.84375
# step :850 Accuracy : 0.875
# step :851 Accuracy : 0.84375
# step :852 Accuracy : 0.875
# step :853 Accuracy : 0.90625
# step :854 Accuracy : 0.8125
# step :855 Accuracy : 0.8125
# step :856 Accuracy : 0.8125
# step :857 Accuracy : 0.875
# step :858 Accuracy : 0.8125
# step :859 Accuracy : 0.75
# step :860 Accuracy : 0.84375
# step :861 Accuracy : 0.78125
# step :862 Accuracy : 0.84375
# step :863 Accuracy : 0.75
# step :864 Accuracy : 0.78125
# step :865 Accuracy : 0.9375
# step :866 Accuracy : 0.8125
# step :867 Accuracy : 0.875
# step :868 Accuracy : 0.78125
# step :869 Accuracy : 0.875
# step :870 Accuracy : 0.84375
# step :871 Accuracy : 0.875
# step :872 Accuracy : 0.875
# step :873 Accuracy : 0.9375
# step :874 Accuracy : 0.8125
# step :875 Accuracy : 0.8125
# step :876 Accuracy : 0.84375
# step :877 Accuracy : 0.90625
# step :878 Accuracy : 0.84375
# step :879 Accuracy : 0.75
# step :880 Accuracy : 0.8125
# step :881 Accuracy : 0.84375
# step :882 Accuracy : 0.75
# step :883 Accuracy : 0.9375
# step :884 Accuracy : 0.84375
# step :885 Accuracy : 0.875
# step :886 Accuracy : 0.71875
# step :887 Accuracy : 0.78125
# step :888 Accuracy : 0.84375
# step :889 Accuracy : 0.84375
# step :890 Accuracy : 0.875
# step :891 Accuracy : 0.84375
# step :892 Accuracy : 0.8125
# step :893 Accuracy : 0.875
# step :894 Accuracy : 0.875
# step :895 Accuracy : 0.875
# step :896 Accuracy : 0.75
# step :897 Accuracy : 0.84375
# step :898 Accuracy : 0.8125
# step :899 Accuracy : 0.84375
# step :900 Accuracy : 0.8125
# step :901 Accuracy : 0.96875
# step :902 Accuracy : 0.9375
# step :903 Accuracy : 0.90625
# step :904 Accuracy : 0.84375
# step :905 Accuracy : 0.96875
# step :906 Accuracy : 0.8125
# step :907 Accuracy : 0.90625
# step :908 Accuracy : 0.8125
# step :909 Accuracy : 0.84375
# step :910 Accuracy : 0.9375
# step :911 Accuracy : 0.8125
# step :912 Accuracy : 0.875
# step :913 Accuracy : 0.9375
# step :914 Accuracy : 0.90625
# step :915 Accuracy : 0.78125
# step :916 Accuracy : 0.84375
# step :917 Accuracy : 0.9375
# step :918 Accuracy : 0.90625
# step :919 Accuracy : 0.90625
# step :920 Accuracy : 0.71875
# step :921 Accuracy : 0.8125
# step :922 Accuracy : 0.875
# step :923 Accuracy : 0.84375
# step :924 Accuracy : 0.96875
# step :925 Accuracy : 0.875
# step :926 Accuracy : 0.9375
# step :927 Accuracy : 0.84375
# step :928 Accuracy : 0.90625
# step :929 Accuracy : 0.875
# step :930 Accuracy : 0.90625
# step :931 Accuracy : 0.875
# step :932 Accuracy : 0.875
# step :933 Accuracy : 0.78125
# step :934 Accuracy : 0.90625
# step :935 Accuracy : 0.90625
# step :936 Accuracy : 0.90625
# step :937 Accuracy : 0.8125
# step :938 Accuracy : 0.78125
# step :939 Accuracy : 0.90625
# step :940 Accuracy : 0.78125
# step :941 Accuracy : 0.71875
# step :942 Accuracy : 0.75
# step :943 Accuracy : 0.875
# step :944 Accuracy : 0.84375
# step :945 Accuracy : 0.78125
# step :946 Accuracy : 0.84375
# step :947 Accuracy : 0.96875
# step :948 Accuracy : 0.875
# step :949 Accuracy : 0.84375
# step :950 Accuracy : 0.90625
# step :951 Accuracy : 0.875
# step :952 Accuracy : 0.875
# step :953 Accuracy : 0.90625
# step :954 Accuracy : 0.78125
# step :955 Accuracy : 0.9375
# step :956 Accuracy : 0.9375
# step :957 Accuracy : 0.84375
# step :958 Accuracy : 0.90625
# step :959 Accuracy : 0.84375
# step :960 Accuracy : 0.90625
# step :961 Accuracy : 0.90625
# step :962 Accuracy : 0.8125
# step :963 Accuracy : 0.78125
# step :964 Accuracy : 0.8125
# step :965 Accuracy : 0.96875
# step :966 Accuracy : 0.75
# step :967 Accuracy : 0.71875
# step :968 Accuracy : 0.90625
# step :969 Accuracy : 0.84375
# step :970 Accuracy : 0.71875
# step :971 Accuracy : 0.875
# step :972 Accuracy : 0.78125
# step :973 Accuracy : 0.8125
# step :974 Accuracy : 0.90625
# step :975 Accuracy : 0.9375
# step :976 Accuracy : 0.90625
# step :977 Accuracy : 0.8125
# step :978 Accuracy : 0.90625
# step :979 Accuracy : 0.65625
# step :980 Accuracy : 0.78125
# step :981 Accuracy : 0.84375
# step :982 Accuracy : 0.875
# step :983 Accuracy : 0.96875
# step :984 Accuracy : 0.90625
# step :985 Accuracy : 0.90625
# step :986 Accuracy : 0.875
# step :987 Accuracy : 0.9375
# step :988 Accuracy : 0.875
# step :989 Accuracy : 0.9375
# step :990 Accuracy : 0.78125
# step :991 Accuracy : 0.875
# step :992 Accuracy : 0.75
# step :993 Accuracy : 0.84375
# step :994 Accuracy : 0.90625
# step :995 Accuracy : 0.8125
# step :996 Accuracy : 0.875
# step :997 Accuracy : 0.8125
# step :998 Accuracy : 0.71875
# step :999 Accuracy : 0.78125
# step :1000 Accuracy : 0.78125
# step :1001 Accuracy : 0.78125
# step :1002 Accuracy : 0.84375
# step :1003 Accuracy : 0.90625
# step :1004 Accuracy : 0.84375
# step :1005 Accuracy : 0.78125
# step :1006 Accuracy : 0.875
# step :1007 Accuracy : 0.71875
# step :1008 Accuracy : 0.71875
# step :1009 Accuracy : 0.875
# step :1010 Accuracy : 0.875
# step :1011 Accuracy : 0.90625
# step :1012 Accuracy : 0.90625
# step :1013 Accuracy : 0.78125
# step :1014 Accuracy : 0.6875
# step :1015 Accuracy : 0.875
# step :1016 Accuracy : 0.78125
# step :1017 Accuracy : 0.8125
# step :1018 Accuracy : 0.9375
# step :1019 Accuracy : 0.75
# step :1020 Accuracy : 0.96875
# step :1021 Accuracy : 0.875
# step :1022 Accuracy : 0.71875
# step :1023 Accuracy : 0.96875
# step :1024 Accuracy : 0.875
# step :1025 Accuracy : 0.84375
# step :1026 Accuracy : 0.75
# step :1027 Accuracy : 0.6875
# step :1028 Accuracy : 0.71875
# step :1029 Accuracy : 0.8125
# step :1030 Accuracy : 0.75
# step :1031 Accuracy : 0.84375
# step :1032 Accuracy : 0.8125
# step :1033 Accuracy : 0.90625
# step :1034 Accuracy : 0.875
# step :1035 Accuracy : 0.875
# step :1036 Accuracy : 0.875
# step :1037 Accuracy : 0.84375
# step :1038 Accuracy : 1.0
# step :1039 Accuracy : 0.9375
# step :1040 Accuracy : 0.84375
# step :1041 Accuracy : 0.90625
# step :1042 Accuracy : 0.84375
# step :1043 Accuracy : 0.875
# step :1044 Accuracy : 0.8125
# step :1045 Accuracy : 0.84375
# step :1046 Accuracy : 0.90625
# step :1047 Accuracy : 0.84375
# step :1048 Accuracy : 0.90625
# step :1049 Accuracy : 0.875
# step :1050 Accuracy : 0.9375
# step :1051 Accuracy : 0.78125
# step :1052 Accuracy : 0.75
# step :1053 Accuracy : 0.9375
# step :1054 Accuracy : 0.84375
# step :1055 Accuracy : 0.875
# step :1056 Accuracy : 0.78125
# step :1057 Accuracy : 0.6875
# step :1058 Accuracy : 0.875
# step :1059 Accuracy : 0.84375
# step :1060 Accuracy : 0.8125
# step :1061 Accuracy : 0.8125
# step :1062 Accuracy : 0.90625
# step :1063 Accuracy : 0.875
# step :1064 Accuracy : 0.9375
# step :1065 Accuracy : 0.875
# step :1066 Accuracy : 0.90625
# step :1067 Accuracy : 0.84375
# step :1068 Accuracy : 0.6875
# step :1069 Accuracy : 0.78125
# step :1070 Accuracy : 0.75
# step :1071 Accuracy : 0.90625
# step :1072 Accuracy : 0.90625
# step :1073 Accuracy : 0.71875
# step :1074 Accuracy : 0.8125
# step :1075 Accuracy : 0.8125
# step :1076 Accuracy : 0.90625
# step :1077 Accuracy : 0.90625
# step :1078 Accuracy : 0.84375
# step :1079 Accuracy : 0.84375
# step :1080 Accuracy : 0.71875
# step :1081 Accuracy : 0.9375
# step :1082 Accuracy : 0.96875
# step :1083 Accuracy : 0.75
# step :1084 Accuracy : 0.84375
# step :1085 Accuracy : 0.875
# step :1086 Accuracy : 0.8125
# step :1087 Accuracy : 0.9375
# step :1088 Accuracy : 0.6875
# step :1089 Accuracy : 0.875
# step :1090 Accuracy : 0.875
# step :1091 Accuracy : 0.84375
# step :1092 Accuracy : 0.8125
# step :1093 Accuracy : 0.90625
# step :1094 Accuracy : 0.71875
# step :1095 Accuracy : 0.78125
# step :1096 Accuracy : 0.84375
# step :1097 Accuracy : 0.84375
# step :1098 Accuracy : 0.90625
# step :1099 Accuracy : 0.75
# step :1100 Accuracy : 0.90625
# step :1101 Accuracy : 0.78125
# step :1102 Accuracy : 0.8125
# step :1103 Accuracy : 0.90625
# step :1104 Accuracy : 0.6875
# step :1105 Accuracy : 0.78125
# step :1106 Accuracy : 0.90625
# step :1107 Accuracy : 0.84375
# step :1108 Accuracy : 0.90625
# step :1109 Accuracy : 0.90625
# step :1110 Accuracy : 0.875
# step :1111 Accuracy : 0.90625
# step :1112 Accuracy : 0.9375
# step :1113 Accuracy : 0.875
# step :1114 Accuracy : 0.71875
# step :1115 Accuracy : 0.90625
# step :1116 Accuracy : 0.90625
# step :1117 Accuracy : 0.875
# step :1118 Accuracy : 0.875
# step :1119 Accuracy : 0.9375
# step :1120 Accuracy : 0.75
# step :1121 Accuracy : 0.71875
# step :1122 Accuracy : 0.8125
# step :1123 Accuracy : 0.8125
# step :1124 Accuracy : 0.8125
# step :1125 Accuracy : 0.875
# step :1126 Accuracy : 0.90625
# step :1127 Accuracy : 0.8125
# step :1128 Accuracy : 0.78125
# step :1129 Accuracy : 0.9375
# step :1130 Accuracy : 0.90625
# step :1131 Accuracy : 0.875
# step :1132 Accuracy : 0.84375
# step :1133 Accuracy : 0.78125
# step :1134 Accuracy : 0.75
# step :1135 Accuracy : 0.84375
# step :1136 Accuracy : 0.78125
# step :1137 Accuracy : 0.9375
# step :1138 Accuracy : 0.9375
# step :1139 Accuracy : 0.9375
# step :1140 Accuracy : 0.90625
# step :1141 Accuracy : 0.8125
# step :1142 Accuracy : 0.78125
# step :1143 Accuracy : 0.96875
# step :1144 Accuracy : 0.875
# step :1145 Accuracy : 0.78125
# step :1146 Accuracy : 0.84375
# step :1147 Accuracy : 0.96875
# step :1148 Accuracy : 0.84375
# step :1149 Accuracy : 0.90625
# step :1150 Accuracy : 0.875
# step :1151 Accuracy : 0.84375
# step :1152 Accuracy : 0.8125
# step :1153 Accuracy : 0.875
# step :1154 Accuracy : 0.9375
# step :1155 Accuracy : 0.75
# step :1156 Accuracy : 0.84375
# step :1157 Accuracy : 0.84375
# step :1158 Accuracy : 0.90625
# step :1159 Accuracy : 0.84375
# step :1160 Accuracy : 0.8125
# step :1161 Accuracy : 0.875
# step :1162 Accuracy : 0.96875
# step :1163 Accuracy : 0.9375
# step :1164 Accuracy : 0.875
# step :1165 Accuracy : 0.875
# step :1166 Accuracy : 0.78125
# step :1167 Accuracy : 0.71875
# step :1168 Accuracy : 0.9375
# step :1169 Accuracy : 0.75
# step :1170 Accuracy : 0.84375
# step :1171 Accuracy : 0.90625
# step :1172 Accuracy : 0.9375
# step :1173 Accuracy : 0.84375
# step :1174 Accuracy : 0.8125
# step :1175 Accuracy : 0.875
# step :1176 Accuracy : 0.84375
# step :1177 Accuracy : 0.90625
# step :1178 Accuracy : 0.84375
# step :1179 Accuracy : 0.75
# step :1180 Accuracy : 0.84375
# step :1181 Accuracy : 0.8125
# step :1182 Accuracy : 0.90625
# step :1183 Accuracy : 0.9375
# step :1184 Accuracy : 0.78125
# step :1185 Accuracy : 0.90625
# step :1186 Accuracy : 0.84375
# step :1187 Accuracy : 0.78125
# step :1188 Accuracy : 0.9375
# step :1189 Accuracy : 0.875
# step :1190 Accuracy : 0.9375
# step :1191 Accuracy : 0.84375
# step :1192 Accuracy : 0.8125
# step :1193 Accuracy : 0.84375
# step :1194 Accuracy : 0.75
# step :1195 Accuracy : 0.8125
# step :1196 Accuracy : 0.875
# step :1197 Accuracy : 0.875
# step :1198 Accuracy : 0.90625
# step :1199 Accuracy : 0.875
# step :1200 Accuracy : 0.90625
# step :1201 Accuracy : 0.84375
# step :1202 Accuracy : 0.84375
# step :1203 Accuracy : 0.78125
# step :1204 Accuracy : 0.8125
# step :1205 Accuracy : 0.84375
# step :1206 Accuracy : 0.78125
# step :1207 Accuracy : 0.90625
# step :1208 Accuracy : 0.84375
# step :1209 Accuracy : 0.9375
# step :1210 Accuracy : 0.8125
# step :1211 Accuracy : 0.9375
# step :1212 Accuracy : 0.8125
# step :1213 Accuracy : 0.90625
# step :1214 Accuracy : 0.84375
# step :1215 Accuracy : 0.78125
# step :1216 Accuracy : 0.8125
# step :1217 Accuracy : 0.71875
# step :1218 Accuracy : 0.84375
# step :1219 Accuracy : 0.8125
# step :1220 Accuracy : 0.90625
# step :1221 Accuracy : 0.90625
# step :1222 Accuracy : 0.6875
# step :1223 Accuracy : 0.9375
# step :1224 Accuracy : 0.84375
# step :1225 Accuracy : 0.78125
# step :1226 Accuracy : 0.8125
# step :1227 Accuracy : 0.8125
# step :1228 Accuracy : 0.71875
# step :1229 Accuracy : 0.90625
# step :1230 Accuracy : 0.90625
# step :1231 Accuracy : 0.90625
# step :1232 Accuracy : 0.90625
# step :1233 Accuracy : 0.90625
# step :1234 Accuracy : 0.84375
# step :1235 Accuracy : 0.90625
# step :1236 Accuracy : 0.875
# step :1237 Accuracy : 0.8125
# step :1238 Accuracy : 0.65625
# step :1239 Accuracy : 0.8125
# step :1240 Accuracy : 0.8125
# step :1241 Accuracy : 0.8125
# step :1242 Accuracy : 0.875
# step :1243 Accuracy : 0.875
# step :1244 Accuracy : 0.8125
# step :1245 Accuracy : 0.90625
# step :1246 Accuracy : 0.875
# step :1247 Accuracy : 0.71875
# step :1248 Accuracy : 0.875
# step :1249 Accuracy : 0.8125
# step :1250 Accuracy : 0.90625
# step :1251 Accuracy : 0.96875
# step :1252 Accuracy : 0.9375
# step :1253 Accuracy : 0.875
# step :1254 Accuracy : 0.90625
# step :1255 Accuracy : 0.9375
# step :1256 Accuracy : 0.875
# step :1257 Accuracy : 0.84375
# step :1258 Accuracy : 0.75
# step :1259 Accuracy : 0.8125
# step :1260 Accuracy : 0.84375
# step :1261 Accuracy : 0.9375
# step :1262 Accuracy : 0.78125
# step :1263 Accuracy : 0.84375
# step :1264 Accuracy : 0.875
# step :1265 Accuracy : 0.84375
# step :1266 Accuracy : 0.8125
# step :1267 Accuracy : 0.8125
# step :1268 Accuracy : 0.8125
# step :1269 Accuracy : 0.875
# step :1270 Accuracy : 0.875
# step :1271 Accuracy : 0.84375
# step :1272 Accuracy : 0.90625
# step :1273 Accuracy : 0.90625
# step :1274 Accuracy : 0.84375
# step :1275 Accuracy : 0.84375
# step :1276 Accuracy : 0.84375
# step :1277 Accuracy : 0.8125
# step :1278 Accuracy : 0.84375
# step :1279 Accuracy : 0.9375
# step :1280 Accuracy : 0.84375
# step :1281 Accuracy : 0.75
# step :1282 Accuracy : 0.84375
# step :1283 Accuracy : 0.875
# step :1284 Accuracy : 0.84375
# step :1285 Accuracy : 0.90625
# step :1286 Accuracy : 0.875
# step :1287 Accuracy : 0.78125
# step :1288 Accuracy : 0.96875
# step :1289 Accuracy : 0.75
# step :1290 Accuracy : 0.90625
# step :1291 Accuracy : 0.875
# step :1292 Accuracy : 0.9375
# step :1293 Accuracy : 0.84375
# step :1294 Accuracy : 0.71875
# step :1295 Accuracy : 0.71875
# step :1296 Accuracy : 0.875
# step :1297 Accuracy : 0.875
# step :1298 Accuracy : 0.875
# step :1299 Accuracy : 0.84375
# step :1300 Accuracy : 0.78125
# step :1301 Accuracy : 0.84375
# step :1302 Accuracy : 0.8125
# step :1303 Accuracy : 0.90625
# step :1304 Accuracy : 0.90625
# step :1305 Accuracy : 0.84375
# step :1306 Accuracy : 0.78125
# step :1307 Accuracy : 0.90625
# step :1308 Accuracy : 0.84375
# step :1309 Accuracy : 0.875
# step :1310 Accuracy : 0.90625
# step :1311 Accuracy : 0.90625
# step :1312 Accuracy : 0.8125
# step :1313 Accuracy : 0.78125
# step :1314 Accuracy : 0.90625
# step :1315 Accuracy : 0.9375
# step :1316 Accuracy : 0.71875
# step :1317 Accuracy : 0.90625
# step :1318 Accuracy : 0.84375
# step :1319 Accuracy : 0.9375
# step :1320 Accuracy : 0.875
# step :1321 Accuracy : 0.875
# step :1322 Accuracy : 0.90625
# step :1323 Accuracy : 0.78125
# step :1324 Accuracy : 0.9375
# step :1325 Accuracy : 0.90625
# step :1326 Accuracy : 0.9375
# step :1327 Accuracy : 0.75
# step :1328 Accuracy : 0.96875
# step :1329 Accuracy : 0.84375
# step :1330 Accuracy : 0.90625
# step :1331 Accuracy : 0.8125
# step :1332 Accuracy : 0.84375
# step :1333 Accuracy : 0.84375
# step :1334 Accuracy : 0.8125
# step :1335 Accuracy : 0.6875
# step :1336 Accuracy : 0.8125
# step :1337 Accuracy : 0.78125
# step :1338 Accuracy : 0.84375
# step :1339 Accuracy : 0.90625
# step :1340 Accuracy : 0.84375
# step :1341 Accuracy : 0.8125
# step :1342 Accuracy : 0.71875
# step :1343 Accuracy : 0.78125
# step :1344 Accuracy : 0.90625
# step :1345 Accuracy : 0.84375
# step :1346 Accuracy : 0.84375
# step :1347 Accuracy : 0.71875
# step :1348 Accuracy : 0.9375
# step :1349 Accuracy : 0.875
# step :1350 Accuracy : 0.84375
# step :1351 Accuracy : 0.84375
# step :1352 Accuracy : 0.90625
# step :1353 Accuracy : 0.78125
# step :1354 Accuracy : 0.8125
# step :1355 Accuracy : 0.78125
# step :1356 Accuracy : 0.84375
# step :1357 Accuracy : 0.84375
# step :1358 Accuracy : 0.75
# step :1359 Accuracy : 0.90625
# step :1360 Accuracy : 0.8125
# step :1361 Accuracy : 0.84375
# step :1362 Accuracy : 0.84375
# step :1363 Accuracy : 0.75
# step :1364 Accuracy : 0.90625
# step :1365 Accuracy : 0.90625
# step :1366 Accuracy : 0.875
# step :1367 Accuracy : 0.90625
# step :1368 Accuracy : 0.75
# step :1369 Accuracy : 0.875
# step :1370 Accuracy : 0.90625
# step :1371 Accuracy : 0.71875
# step :1372 Accuracy : 0.8125
# step :1373 Accuracy : 0.875
# step :1374 Accuracy : 0.78125
# step :1375 Accuracy : 0.78125
# step :1376 Accuracy : 0.84375
# step :1377 Accuracy : 0.75
# step :1378 Accuracy : 0.90625
# step :1379 Accuracy : 0.78125
# step :1380 Accuracy : 0.8125
# step :1381 Accuracy : 0.8125
# step :1382 Accuracy : 0.8125
# step :1383 Accuracy : 0.8125
# step :1384 Accuracy : 0.9375
# step :1385 Accuracy : 0.78125
# step :1386 Accuracy : 0.78125
# step :1387 Accuracy : 0.875
# step :1388 Accuracy : 0.84375
# step :1389 Accuracy : 0.78125
# step :1390 Accuracy : 0.6875
# step :1391 Accuracy : 0.75
# step :1392 Accuracy : 0.71875
# step :1393 Accuracy : 0.875
# step :1394 Accuracy : 0.78125
# step :1395 Accuracy : 0.9375
# step :1396 Accuracy : 0.78125
# step :1397 Accuracy : 0.90625
# step :1398 Accuracy : 0.90625
# step :1399 Accuracy : 0.875
# step :1400 Accuracy : 0.90625
# step :1401 Accuracy : 0.875
# step :1402 Accuracy : 0.84375
# step :1403 Accuracy : 0.90625
# step :1404 Accuracy : 0.90625
# step :1405 Accuracy : 0.875
# step :1406 Accuracy : 0.71875
# step :1407 Accuracy : 0.90625
# step :1408 Accuracy : 0.9375
# step :1409 Accuracy : 0.84375
# step :1410 Accuracy : 0.78125
# step :1411 Accuracy : 0.71875
# step :1412 Accuracy : 0.9375
# step :1413 Accuracy : 0.9375
# step :1414 Accuracy : 0.8125
# step :1415 Accuracy : 0.71875
# step :1416 Accuracy : 0.84375
# step :1417 Accuracy : 0.9375
# step :1418 Accuracy : 0.90625
# step :1419 Accuracy : 0.9375
# step :1420 Accuracy : 0.71875
# step :1421 Accuracy : 0.875
# step :1422 Accuracy : 0.8125
# step :1423 Accuracy : 0.75
# step :1424 Accuracy : 0.90625
# step :1425 Accuracy : 0.90625
# step :1426 Accuracy : 0.875
# step :1427 Accuracy : 0.8125
# step :1428 Accuracy : 0.75
# step :1429 Accuracy : 0.78125
# step :1430 Accuracy : 1.0
# step :1431 Accuracy : 0.9375
# step :1432 Accuracy : 0.875
# step :1433 Accuracy : 0.78125
# step :1434 Accuracy : 0.8125
# step :1435 Accuracy : 0.84375
# step :1436 Accuracy : 0.9375
# step :1437 Accuracy : 0.75
# step :1438 Accuracy : 0.8125
# step :1439 Accuracy : 0.875
# step :1440 Accuracy : 0.90625
# step :1441 Accuracy : 0.84375
# step :1442 Accuracy : 0.875
# step :1443 Accuracy : 0.78125
# step :1444 Accuracy : 0.75
# step :1445 Accuracy : 0.78125
# step :1446 Accuracy : 0.875
# step :1447 Accuracy : 0.8125
# step :1448 Accuracy : 0.875
# step :1449 Accuracy : 0.9375
# step :1450 Accuracy : 0.78125
# step :1451 Accuracy : 0.875
# step :1452 Accuracy : 0.65625
# step :1453 Accuracy : 0.96875
# step :1454 Accuracy : 0.6875
# step :1455 Accuracy : 0.78125
# step :1456 Accuracy : 0.9375
# step :1457 Accuracy : 0.84375
# step :1458 Accuracy : 0.84375
# step :1459 Accuracy : 0.75
# step :1460 Accuracy : 0.90625
# step :1461 Accuracy : 0.875
# step :1462 Accuracy : 0.875
# step :1463 Accuracy : 0.875
# step :1464 Accuracy : 0.75
# step :1465 Accuracy : 0.90625
# step :1466 Accuracy : 0.875
# step :1467 Accuracy : 0.875
# step :1468 Accuracy : 0.8125
# step :1469 Accuracy : 0.84375
# step :1470 Accuracy : 0.90625
# step :1471 Accuracy : 0.84375
# step :1472 Accuracy : 0.8125
# step :1473 Accuracy : 0.84375
# step :1474 Accuracy : 0.84375
# step :1475 Accuracy : 0.875
# step :1476 Accuracy : 0.875
# step :1477 Accuracy : 0.78125
# step :1478 Accuracy : 0.71875
# step :1479 Accuracy : 0.84375
# step :1480 Accuracy : 0.875
# step :1481 Accuracy : 0.875
# step :1482 Accuracy : 0.8125
# step :1483 Accuracy : 0.8125
# step :1484 Accuracy : 0.9375
# step :1485 Accuracy : 0.8125
# step :1486 Accuracy : 0.90625
# step :1487 Accuracy : 0.71875
# step :1488 Accuracy : 0.9375
# step :1489 Accuracy : 0.84375
# step :1490 Accuracy : 0.78125
# step :1491 Accuracy : 0.90625
# step :1492 Accuracy : 0.75
# step :1493 Accuracy : 0.9375
# step :1494 Accuracy : 0.84375
# step :1495 Accuracy : 0.8125
# step :1496 Accuracy : 0.875
# step :1497 Accuracy : 0.9375
# step :1498 Accuracy : 0.84375
# step :1499 Accuracy : 0.8125
# step :1500 Accuracy : 0.84375
# step :1501 Accuracy : 0.78125
# step :1502 Accuracy : 0.875
# step :1503 Accuracy : 0.875
# step :1504 Accuracy : 0.75
# step :1505 Accuracy : 0.84375
# step :1506 Accuracy : 0.78125
# step :1507 Accuracy : 0.90625
# step :1508 Accuracy : 0.78125
# step :1509 Accuracy : 0.90625
# step :1510 Accuracy : 0.75
# step :1511 Accuracy : 0.8125
# step :1512 Accuracy : 0.90625
# step :1513 Accuracy : 0.9375
# step :1514 Accuracy : 0.78125
# step :1515 Accuracy : 0.8125
# step :1516 Accuracy : 0.625
# step :1517 Accuracy : 0.84375
# step :1518 Accuracy : 0.75
# step :1519 Accuracy : 0.75
# step :1520 Accuracy : 0.8125
# step :1521 Accuracy : 0.84375
# step :1522 Accuracy : 0.78125
# step :1523 Accuracy : 0.84375
# step :1524 Accuracy : 0.875
# step :1525 Accuracy : 0.90625
# step :1526 Accuracy : 0.84375
# step :1527 Accuracy : 0.875
# step :1528 Accuracy : 0.8125
# step :1529 Accuracy : 0.78125
# step :1530 Accuracy : 0.625
# step :1531 Accuracy : 0.84375
# step :1532 Accuracy : 0.9375
# step :1533 Accuracy : 0.90625
# step :1534 Accuracy : 0.8125
# step :1535 Accuracy : 0.875
# step :1536 Accuracy : 0.78125
# step :1537 Accuracy : 0.71875
# step :1538 Accuracy : 0.96875
# step :1539 Accuracy : 0.875
# step :1540 Accuracy : 0.90625
# step :1541 Accuracy : 0.875
# step :1542 Accuracy : 0.90625
# step :1543 Accuracy : 0.71875
# step :1544 Accuracy : 0.875
# step :1545 Accuracy : 0.84375
# step :1546 Accuracy : 0.6875
# step :1547 Accuracy : 0.90625
# step :1548 Accuracy : 0.875
# step :1549 Accuracy : 0.75
# step :1550 Accuracy : 0.875
# step :1551 Accuracy : 0.8125
# step :1552 Accuracy : 0.9375
# step :1553 Accuracy : 0.9375
# step :1554 Accuracy : 0.8125
# step :1555 Accuracy : 0.90625
# step :1556 Accuracy : 0.90625
# step :1557 Accuracy : 0.78125
# step :1558 Accuracy : 0.78125
# step :1559 Accuracy : 1.0
# step :1560 Accuracy : 0.9375
# step :1561 Accuracy : 0.84375
# step :1562 Accuracy : 0.8125
# Total Accuracy : 0.8483914852752891
